# %%
import requests
from openpyxl import load_workbook
import pandas as pd 
import os

# %%
def saveExcelfromURL(url, fileName, path, sheetName, skipRow):
    global df    
    resp = requests.get(url)
    output = open(fileName, 'wb')
    output.write(resp.content)
    output.close()
    wb = load_workbook(fileName)
    filePath = (path + fileName)
    
    data = pd.read_excel(filePath, sheetName, skiprows=skipRow, index_col=None, na_values=['NA'])
    df = pd.DataFrame(data)

# %%
## as of 2/27/18

url = "http://www.p12.nysed.gov/accountability/documents/AccountabilityStatus2017-18.xlsx"
fileName = "AccountabilityStatus2017-18.xlsx"
##path = "//52CCIFS00/Users$/floza/My Documents/OSFEP/Data Scrape_cDriveCopy/"
path = "/Users/floza/Documents/GitHub/NYCDOE-Data/workbooks/"
sheetName = "Sheet1"
skipRow = 4

saveExcelfromURL(url, fileName, path, sheetName, skipRow)
df_SY18 = df
df_SY18.head()
# Out:
#    Unnamed: 0      BEDS_CD                            NAME  TYPE        DBEDS  \
# 0         NaN  10100010000                  ALBANY CITY SD     3  10100010000
# 1         NaN  10100010014        MONTESSORI MAGNET SCHOOL     1  10100010000
# 2         NaN  10100010016    PINE HILLS ELEMENTARY SCHOOL     1  10100010000
# 3         NaN  10100010018       DELAWARE COMMUNITY SCHOOL     1  10100010000
# 4         NaN  10100010019  NEW SCOTLAND ELEMENTARY SCHOOL     1  10100010000
#
#             DNAME                           BOCES  \
# 0  ALBANY CITY SD  ALBANY-SCHOH-SCHENECTADY-SARAT
# 1  ALBANY CITY SD  ALBANY-SCHOH-SCHENECTADY-SARAT
# 2  ALBANY CITY SD  ALBANY-SCHOH-SCHENECTADY-SARAT
# 3  ALBANY CITY SD  ALBANY-SCHOH-SCHENECTADY-SARAT
# 4  ALBANY CITY SD  ALBANY-SCHOH-SCHENECTADY-SARAT
#
#   2015-16 School Title I Status  \
# 0                           NaN
# 1            Schoolwide Program
# 2            Schoolwide Program
# 3            Schoolwide Program
# 4            Schoolwide Program
#
#   2017-18 Accountability Status, effective January 10, 2018  \
# 0                                     Focus District
# 1                                      Good Standing
# 2                                       Focus School
# 3                                       Focus School
# 4                                       Focus School
#
#   Re-Identified Status, effective February 26, 2017  \
# 0                      Re-identified Focus District
# 1                                               NaN
# 2                        Re-identified Focus School
# 3                        Re-identified Focus School
# 4                        Re-identified Focus School
#
#   Persistently Struggling/ Struggling School Status
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
## as of 12/20/16

url = "http://www.p12.nysed.gov/accountability/documents/AccountabilityStatus2016-17.xlsx"
fileName = "AccountabilityStatus2016-17.xlsx"
##path = "//52CCIFS00/Users$/floza/My Documents/OSFEP/Data Scrape_cDriveCopy/"
sheetName = "Sheet1"
skipRow = 4

saveExcelfromURL(url, fileName, path, sheetName, skipRow)
df_SY17 = df
df_SY17.head()
# Out:
#    Unnamed: 0       BEDS_CD       NCES ID                                NAME  \
# 0         NaN  660413020000  3.602300e+06                         ABBOTT UFSD
# 1         NaN  660413020002  3.602300e+11                       ABBOTT SCHOOL
# 2         NaN  320700860957  3.601001e+11  ACADEMIC LEADERSHIP CHARTER SCHOOL
# 3         NaN  280201860934  3.600997e+11              ACADEMY CHARTER SCHOOL
# 4         NaN  343000860998  3.601053e+11  ACADEMY OF THE CITY CHARTER SCHOOL
#
#    TYPE         DBEDS                               DNAME  \
# 0     3  660413020000                         ABBOTT UFSD
# 1     1  660413020000                         ABBOTT UFSD
# 2     9  320700860957  ACADEMIC LEADERSHIP CHARTER SCHOOL
# 3     9  280201860934              ACADEMY CHARTER SCHOOL
# 4     9  343000860998  ACADEMY OF THE CITY CHARTER SCHOOL
#
#                   BOCES 2014-15 School Title I Status  \
# 0  SOUTHERN WESTCHESTER                           NaN
# 1  SOUTHERN WESTCHESTER                           NaN
# 2                   NaN            Schoolwide Program
# 3                NASSAU           Targeted Assistance
# 4                   NaN            Schoolwide Program
#
#   2015-16 Accountability Status  2016-17 Accountability Status  \
# 0                  Good Standing                 Good Standing
# 1                  Good Standing                 Good Standing
# 2                  Good Standing                 Good Standing
# 3                  Good Standing                 Good Standing
# 4                  Good Standing                 Good Standing
#
#   Re-Identified Status Persistently Struggling/ Struggling School Status
# 0                  NaN                                               NaN
# 1                  NaN                                               NaN
# 2                  NaN                                               NaN
# 3                  NaN                                               NaN
# 4                  NaN                                               NaN

# %%
df_SY17 = df_SY17.drop(df_SY17.columns[0], axis=1) #axis 1 = columns
df_SY18 = df_SY18.drop(df_SY18.columns[0], axis=1) #axis 1 = columns

# %%
df_SY17 = df_SY17.drop(df_SY17.iloc[:, 1:7], axis=1) #axis 1 = columns
df_SY17.head()
# Out:
#         BEDS_CD 2014-15 School Title I Status 2015-16 Accountability Status   \
# 0  660413020000                           NaN                  Good Standing
# 1  660413020002                           NaN                  Good Standing
# 2  320700860957            Schoolwide Program                  Good Standing
# 3  280201860934           Targeted Assistance                  Good Standing
# 4  343000860998            Schoolwide Program                  Good Standing
#
#   2016-17 Accountability Status Re-Identified Status  \
# 0                 Good Standing                  NaN
# 1                 Good Standing                  NaN
# 2                 Good Standing                  NaN
# 3                 Good Standing                  NaN
# 4                 Good Standing                  NaN
#
#   Persistently Struggling/ Struggling School Status
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
sedACCT = pd.merge(df_SY18, df_SY17, how='left', on='BEDS_CD')

# %%
sedACCT.shape
# Out:
# (5383, 15)

# %%
sedACCT = sedACCT[(sedACCT['BEDS_CD']  > 300000000000) & (sedACCT['BEDS_CD'] < 400000000000)]
sedACCT.shape
# Out:
# (1796, 15)

# %%
path = "D:/OneDrive - NYCDOE/OSI Data & Analytics/Python/"
fileName = "SED_Accountability" + ".xls"

sedACCT.to_excel(path+fileName)
